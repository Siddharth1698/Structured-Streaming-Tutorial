# %%
import pandas as pd
from kafka import KafkaProducer
from datetime import datetime
import time
import random
import numpy as np

# pip install kafka-python

KAFKA_TOPIC_NAME_CONS = "Topic"
KAFKA_BOOTSTRAP_SERVERS_CONS = 'localhost:9092'

if __name__ == "__main__":
    print("Kafka Producer Application Started ... ")

    kafka_producer_obj = KafkaProducer(bootstrap_servers=KAFKA_BOOTSTRAP_SERVERS_CONS,
                                       value_serializer=lambda x: x.encode('utf-8'))
    
    filepath = "IRIS.csv"
    
    flower_df = pd.read_csv(filepath)
  
    flower_df['order_id'] = np.arange(len(flower_df))

    
    flower_list = flower_df.to_dict(orient="records")
       

    message_list = []
    message = None
    for message in flower_list:
        
        message_fields_value_list = []
               
        message_fields_value_list.append(message["order_id"])
        message_fields_value_list.append(message["sepal_length"])
        message_fields_value_list.append(message["sepal_width"])
        message_fields_value_list.append(message["petal_length"])
        message_fields_value_list.append(message["petal_width"])
        message_fields_value_list.append(message["species"])

        message = ','.join(str(v) for v in message_fields_value_list)
        print("Message Type: ", type(message))
        print("Message: ", message)
        kafka_producer_obj.send(KAFKA_TOPIC_NAME_CONS, message)
        time.sleep(1)


    print("Kafka Producer Application Completed. ")
# Out:
# Kafka Producer Application Started ...
# Message Type:  <class 'str'>
# Message:  0,5.1,3.5,1.4,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  1,4.9,3.0,1.4,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  2,4.7,3.2,1.3,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  3,4.6,3.1,1.5,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  4,5.0,3.6,1.4,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  5,5.4,3.9,1.7,0.4,Iris-setosa
# Message Type:  <class 'str'>
# Message:  6,4.6,3.4,1.4,0.3,Iris-setosa
# Message Type:  <class 'str'>
# Message:  7,5.0,3.4,1.5,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  8,4.4,2.9,1.4,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  9,4.9,3.1,1.5,0.1,Iris-setosa
# Message Type:  <class 'str'>
# Message:  10,5.4,3.7,1.5,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  11,4.8,3.4,1.6,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  12,4.8,3.0,1.4,0.1,Iris-setosa
# Message Type:  <class 'str'>
# Message:  13,4.3,3.0,1.1,0.1,Iris-setosa
# Message Type:  <class 'str'>
# Message:  14,5.8,4.0,1.2,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  15,5.7,4.4,1.5,0.4,Iris-setosa
# Message Type:  <class 'str'>
# Message:  16,5.4,3.9,1.3,0.4,Iris-setosa
# Message Type:  <class 'str'>
# Message:  17,5.1,3.5,1.4,0.3,Iris-setosa
# Message Type:  <class 'str'>
# Message:  18,5.7,3.8,1.7,0.3,Iris-setosa
# Message Type:  <class 'str'>
# Message:  19,5.1,3.8,1.5,0.3,Iris-setosa
# Message Type:  <class 'str'>
# Message:  20,5.4,3.4,1.7,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  21,5.1,3.7,1.5,0.4,Iris-setosa
# Message Type:  <class 'str'>
# Message:  22,4.6,3.6,1.0,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  23,5.1,3.3,1.7,0.5,Iris-setosa
# Message Type:  <class 'str'>
# Message:  24,4.8,3.4,1.9,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  25,5.0,3.0,1.6,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  26,5.0,3.4,1.6,0.4,Iris-setosa
# Message Type:  <class 'str'>
# Message:  27,5.2,3.5,1.5,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  28,5.2,3.4,1.4,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  29,4.7,3.2,1.6,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  30,4.8,3.1,1.6,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  31,5.4,3.4,1.5,0.4,Iris-setosa
# Message Type:  <class 'str'>
# Message:  32,5.2,4.1,1.5,0.1,Iris-setosa
# Message Type:  <class 'str'>
# Message:  33,5.5,4.2,1.4,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  34,4.9,3.1,1.5,0.1,Iris-setosa
# Message Type:  <class 'str'>
# Message:  35,5.0,3.2,1.2,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  36,5.5,3.5,1.3,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  37,4.9,3.1,1.5,0.1,Iris-setosa
# Message Type:  <class 'str'>
# Message:  38,4.4,3.0,1.3,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  39,5.1,3.4,1.5,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  40,5.0,3.5,1.3,0.3,Iris-setosa
# Message Type:  <class 'str'>
# Message:  41,4.5,2.3,1.3,0.3,Iris-setosa
# Message Type:  <class 'str'>
# Message:  42,4.4,3.2,1.3,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  43,5.0,3.5,1.6,0.6,Iris-setosa
# Message Type:  <class 'str'>
# Message:  44,5.1,3.8,1.9,0.4,Iris-setosa
# Message Type:  <class 'str'>
# Message:  45,4.8,3.0,1.4,0.3,Iris-setosa
# Message Type:  <class 'str'>
# Message:  46,5.1,3.8,1.6,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  47,4.6,3.2,1.4,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  48,5.3,3.7,1.5,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  49,5.0,3.3,1.4,0.2,Iris-setosa
# Message Type:  <class 'str'>
# Message:  50,7.0,3.2,4.7,1.4,Iris-versicolor
# Message Type:  <class 'str'>
# Message:  51,6.4,3.2,4.5,1.5,Iris-versicolor
# Message Type:  <class 'str'>
# Message:  52,6.9,3.1,4.9,1.5,Iris-versicolor
# Message Type:  <class 'str'>
# Message:  53,5.5,2.3,4.0,1.3,Iris-versicolor
# Message Type:  <class 'str'>
# Message:  54,6.5,2.8,4.6,1.5,Iris-versicolor
# Message Type:  <class 'str'>
# Message:  55,5.7,2.8,4.5,1.3,Iris-versicolor
# Message Type:  <class 'str'>
# Message:  56,6.3,3.3,4.7,1.6,Iris-versicolor
# Message Type:  <class 'str'>
# Message:  57,4.9,2.4,3.3,1.0,Iris-versicolor
# Message Type:  <class 'str'>
# Message:  58,6.6,2.9,4.6,1.3,Iris-versicolor
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-43ae63656264> in <module>
#      44         print("Message: ", message)
#      45         kafka_producer_obj.send(KAFKA_TOPIC_NAME_CONS, message)
# ---> 46         time.sleep(1)
#      47
#      48
#
# KeyboardInterrupt:

# %%
import pandas as pd
df3 = pd.read_csv('IRIS.csv')
df3.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
